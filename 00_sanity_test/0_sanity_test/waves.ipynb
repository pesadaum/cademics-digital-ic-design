# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./simvision.csv')

df = df.fillna('HiZ')
cdf = df.iloc[1:, :]

cdf
# Out:
#     SimTime register_test.clk register_test.data_in[7:0]  \
# 1         5               1.0                        HiZ
# 2        10               0.0                         55
# 3        15               1.0                         55
# 4        20               0.0                         AA
# 5        25               1.0                         AA
# 6        30               0.0                         FF
# 7        35               1.0                         FF
# 8        40               0.0                         FF
# 9        45               1.0                         FF
# 10       50               0.0                         FF
#
#    register_test.data_out[7:0] register_test.rst
# 1                          HiZ               HiZ
# 2                          HiZ               0.0
# 3                           55               0.0
# 4                           55               0.0
# 5                           AA               0.0
# ...

# %%
plt.step(cdf['SimTime'], cdf['register_test.clk'])

# %%
a = int('FF', 16)
bin(a)
# Out:
# '0b11111111'

# %%
import wavedrom

waves = """{"signal": [
    {"name": "CK",   "wave": "P.......",
        "period": 2},
    {"name": "CMD",  "wave": "x.3x=x4x=x=x=x=x",
        "data": "RAS NOP CAS NOP NOP NOP NOP", "phase": 0.5},
    {"name": "ADDR", "wave": "x.=x..=x........",
        "data": "ROW COL",                     "phase": 0.5},
    {"name": "DQS",  "wave": "z.......0.1010z."},
    {"name": "DQ",   "wave": "z.........5555z.", "data": "D0 D1 D2 D3"}
]}"""
svg = wavedrom.render(waves)
#
#
svg.saveas("demo1.svg")


svg

# %%
wavedrom.render_write(waves, 'waves.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/pesadaum/work/cademics/0_sanity_test/0_sanity_test/waves.ipynb Célula 6 in 1
# ----> <a href='vscode-notebook-cell:/home/pesadaum/work/cademics/0_sanity_test/0_sanity_test/waves.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> wavedrom.render_write(waves, 'waves.pdf')
#
# File ~/.local/lib/python3.8/site-packages/wavedrom/__init__.py:36, in render_write(source, output, strict_js_features)
#      35 def render_write(source, output, strict_js_features = False):
# ---> 36     jinput = source.read()
#      37     out = render(jinput, strict_js_features=strict_js_features)
#      38     out.write(output)
#
# AttributeError: 'str' object has no attribute 'read'

# %%
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPDF



renderPDF.drawToFile(svg, "file.pdf")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/pesadaum/work/cademics/0_sanity_test/0_sanity_test/waves.ipynb Célula 7 in 4
#       <a href='vscode-notebook-cell:/home/pesadaum/work/cademics/0_sanity_test/0_sanity_test/waves.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> from svglib.svglib import svg2rlg
#       <a href='vscode-notebook-cell:/home/pesadaum/work/cademics/0_sanity_test/0_sanity_test/waves.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> from reportlab.graphics import renderPDF
# ----> <a href='vscode-notebook-cell:/home/pesadaum/work/cademics/0_sanity_test/0_sanity_test/waves.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> renderPDF.drawToFile(svg, "file.pdf")
#
# File /usr/lib/python3/dist-packages/reportlab/graphics/renderPDF.py:290, in drawToFile(d, fn, msg, showBoundary, autoSize, canvasKwds)
# ...
